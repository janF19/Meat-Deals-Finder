# %%
import pandas as pd

data = pd.read_csv('recipe_recommendations.csv')

data
# Out:
#                                              product product_english  \
# 0                      Zelenka Krůtí mletý polotovar   ground turkey
# 1                      Zelenka Krůtí mletý polotovar   ground turkey
# 2                  Česká krůta Krůtí mletý polotovar          turkey
# 3                  Česká krůta Krůtí mletý polotovar          turkey
# 4                            MSC Čerstvé mušle Super         mussels
# 5                            MSC Čerstvé mušle Super         mussels
# 6  Sutcha Vepřová krkovice v marinádě pomeranč a ...            pork
# 7  Sutcha Vepřová krkovice v marinádě pomeranč a ...            pork
#
#                                          recipe_name  cooking_time  servings  \
# 0             Blue Cheese and Mushroom Turkey Burger            45         1
# 1  Turkey-Spinach Burgers With Sweet Soy-Ginger S...            45         4
# 2                     Easy Weekday Breakfast Muffins            30        12
# ...

# %%
import pandas as pd

data = pd.read_csv('recipe_recommendations2.csv')

data
# Out:
#                                              product product_english  \
# 0                      Zelenka Krůtí mletý polotovar   ground turkey
# 1                      Zelenka Krůtí mletý polotovar   ground turkey
# 2                  Česká krůta Krůtí mletý polotovar          turkey
# 3                  Česká krůta Krůtí mletý polotovar          turkey
# 4                            MSC Čerstvé mušle Super         mussels
# 5                            MSC Čerstvé mušle Super         mussels
# 6  Sutcha Vepřová krkovice v marinádě pomeranč a ...            pork
#
#                                          recipe_name  cooking_time  servings  \
# 0             Blue Cheese and Mushroom Turkey Burger            45         1
# 1                     Chavrie Stuffed Turkey Burgers            45         6
# 2                     Easy Weekday Breakfast Muffins            30        12
# 3                               Monte Carlo Sandwich            45         9
# ...

# %%
import pandas as pd

recip = pd.read_csv('recipes.csv')

recip[['product', 'product_english', 'recipe_name']]
# Out:
#                                              product product_english  \
# 0                              Gurmet Hovězí tatarák            beef
# 1                              Gurmet Hovězí tatarák            beef
# 2                  Toro Hlavečník Hovězí uzené Bavet            beef
# 3                  Toro Hlavečník Hovězí uzené Bavet            beef
# 4        Nature's Meadow Jehněčí kolínko zadní, 1 ks            lamb
# 5        Nature's Meadow Jehněčí kolínko zadní, 1 ks            lamb
# 6                   Medusa Smažené filety ze sardelí       anchovies
# 7                  Vette & Verhaart Srdcovky čerstvé            beef
# 8                  Vette & Verhaart Srdcovky čerstvé            beef
# 9                          Ecoproduct BIO Hovězí krk            beef
# 10                         Ecoproduct BIO Hovězí krk            beef
# 11  FJORU ASC Krevety vařené loupané na špejli 36/40          shrimp
# 12                 MASO! Hovězí Burger s lojem, 2 ks            beef
# ...

# %%
import pandas as pd

products = pd.read_csv('./rohlikData/products6.csv')


products
# Out:
#     id        date             datetime  \
# 0   31  2025-02-05  2025-02-05 14:47:12
# 1   32  2025-02-05  2025-02-05 14:47:12
# 2   33  2025-02-05  2025-02-05 14:47:12
# 3   34  2025-02-05  2025-02-05 14:47:12
# 4   35  2025-02-05  2025-02-05 14:47:12
# 5   36  2025-02-05  2025-02-05 14:47:12
# 6   37  2025-02-05  2025-02-05 14:47:12
# 7   38  2025-02-05  2025-02-05 14:47:12
# 8   39  2025-02-05  2025-02-05 14:47:12
# 9   40  2025-02-05  2025-02-05 14:47:12
# 10  41  2025-02-05  2025-02-05 14:47:12
# 11  42  2025-02-05  2025-02-05 14:47:12
#
#                                                 name  current_price  \
# 0                              Gurmet Hovězí tatarák          54.94
# 1                      MASO! Vepřové kostky na guláš         164.40
# 2                  Toro Hlavečník Hovězí uzené Bavet         224.60
# 3        Nature's Meadow Jehněčí kolínko zadní, 1 ks         232.01
# 4                   Medusa Smažené filety ze sardelí          71.44
# ...
